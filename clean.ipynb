# %%
# %load_ext autoreload
# %autoreload 2

from scripts.plot_results import *

# Default configuration of parameters
config_default = {'NUM_SITES': 12, 'NUM_ELECTRONS': 12, 'N_UP': 6, 'N_DN': 6, 'T1': 1.0, 'T2': 0.2, 'PHI': 0.5, 'TOL': 1e-9, 'N_FLUX': 4}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tol_list = [1e-6, 1e-7, 1e-8, 1e-9]
config_list = []
for tol in tol_list:
    config_list.append(config_default.copy())
    config_list[-1]['TOL'] = tol

labels = [f'$\eta_{{tol}}=10^{{{int(np.log10(tol))}}}$' for tol in tol_list]

fig_ax = plot_1d_cut(config_list, 'u', {'delta': 0.0, 'v': 0.0}, 
                     ['sdw', 'cdw', 'gap'], [r'$\Delta S_{SDW}$', r'$\Delta S_{CDW}$', r'$\Delta\epsilon_{gap}$'], 
                     r'$U/t$', rf'$\Delta/t=0,\, V/t=0$', labels=labels, xlim=(7.75, 8.5), relative_to=3)

plt.show()

# %%
n_flux_list = [4, 6, 8, 10, 12, 14]
config_list = []
for n_flux in n_flux_list:
    config_list.append(config_default.copy())
    config_list[-1]['N_FLUX'] = n_flux

labels = [rf'$N_{{\phi}}={n_flux**2}$' for n_flux in n_flux_list]

fig_ax = plot_1d_cut(config_list, 'u', {'delta': 0.0, 'v': 0.0}, 'chern', r'$\mathcal{C}$', 
                     r'$U/t$', rf'$\Delta/t=0, V/t=0$', labels=labels, xlim=(6.75, 8.25))

plt.show()
# Out:
# No matching file found for config: {'NUM_SITES': 12, 'NUM_ELECTRONS': 12, 'N_UP': 6, 'N_DN': 6, 'T1': 1.0, 'T2': 0.2, 'PHI': 0.5, 'TOL': 1e-09, 'N_FLUX': 10}
# No matching file found for config: {'NUM_SITES': 12, 'NUM_ELECTRONS': 12, 'N_UP': 6, 'N_DN': 6, 'T1': 1.0, 'T2': 0.2, 'PHI': 0.5, 'TOL': 1e-09, 'N_FLUX': 12}
# No matching file found for config: {'NUM_SITES': 12, 'NUM_ELECTRONS': 12, 'N_UP': 6, 'N_DN': 6, 'T1': 1.0, 'T2': 0.2, 'PHI': 0.5, 'TOL': 1e-09, 'N_FLUX': 14}
